# %%
#immutability

# %%
name = 'mani'

# %%
name[0] = 'P'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f2d6cf6fa9fa> in <module>
# ----> 1 name[0] = 'P'
#
# TypeError: 'str' object does not support item assignment

# %%
last_letters = name[1:4]

# %%
last_letters
# Out:
# 'ani'

# %%
new_one = 'P'

# %%
new_string = new_one + last_letters #concatination

# %%
new_string
# Out:
# 'Pani'

# %%
name
# Out:
# 'mani'
